# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy 
import requests
import json
from api_keys import weather_api_key
from citipy import citipy 
import random
from datetime import date
import scipy.stats as st
weather_date = str(date.today())

# %%
#get random citiets
cities = []
while len(cities) < 1000:
    city = citipy.nearest_city(random.uniform(-90,90),random.uniform(-180,180))
    cities.append(city.city_name)
    #eliminate duplicates
    cities = list(set(cities))

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
#empty lists to add values per city to, and then make df
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
iteration = 0
#loop thru all the cities and print each as data is retreived
for city in cities: 
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}"
        responses = (requests.get(query_url).json())
        iteration += 1
        print(f"getting weather data for {city}(city #{iteration}) ")
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        max_temp.append((responses['main']['temp_max'])-273.15)
        lat.append(responses['coord']['lat'])
        lng.append(responses['coord']['lon'])
        humidity.append(responses['main']['humidity'])
        cloudiness.append(responses['clouds']['all'])
        wind_speed.append(responses['wind']['speed'])
        country.append(responses['sys']['country'])
        date.append(responses['dt'])
        
#if city isnt in api skip it and go to next, append lists with null so list values correspond to cities        
    except:
        KeyError
        print(f'KeyError - {city} Skipped --- next city')
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        max_temp.append(None)
        lat.append(None)
        lng.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        country.append(None)
        date.append(None)
# Out:
# getting weather data for bilibino(city #1)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for lloydminster(city #2)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for aracataca(city #3)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for hithadhoo(city #4)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for grindavik(city #5)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for buariki(city #6)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - buariki Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for kuruman(city #7)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for maumere(city #8)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for sorong(city #9)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for lamar(city #10)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for ouadda(city #11)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for darhan(city #12)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for marsa matruh(city #13)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for copiapo(city #14)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for milkovo(city #15)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for port-cartier(city #16)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for ponta do sol(city #17)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for buraydah(city #18)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for izumo(city #19)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for rungata(city #20)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - rungata Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for loreto(city #21)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for marcona(city #22)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - marcona Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for east london(city #23)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for codajas(city #24)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for ilulissat(city #25)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for nhulunbuy(city #26)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for cagayan de tawi-tawi(city #27)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - cagayan de tawi-tawi Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for saint-pierre(city #28)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for konstantinovka(city #29)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for boksitogorsk(city #30)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for araguaina(city #31)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for shimoda(city #32)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for bereda(city #33)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for pangnirtung(city #34)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for nakamura(city #35)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for sumbawanga(city #36)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for pitimbu(city #37)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for eldorado(city #38)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for saleaula(city #39)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - saleaula Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for gat(city #40)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for khatanga(city #41)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for guapiles(city #42)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for garowe(city #43)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for urumqi(city #44)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for minot(city #45)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for vanimo(city #46)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for mecca(city #47)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for thai binh(city #48)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for oyama(city #49)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for coihaique(city #50)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for kaeo(city #51)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for erie(city #52)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for anicuns(city #53)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for petauke(city #54)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for carutapera(city #55)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for mogadishu(city #56)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for the valley(city #57)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for lingao(city #58)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for kuito(city #59)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for tautira(city #60)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for sabang(city #61)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for amderma(city #62)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - amderma Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for beringovskiy(city #63)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for kamina(city #64)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for paamiut(city #65)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for sattankulam(city #66)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - sattankulam Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for lima(city #67)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for goderich(city #68)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for flinders(city #69)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for lyngseidet(city #70)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for faanui(city #71)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for cabo san lucas(city #72)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for wamba(city #971)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for bongaigaon(city #972)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for beloha(city #973)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for umzimvubu(city #974)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - umzimvubu Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for ishigaki(city #975)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for corinto(city #976)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for butaritari(city #977)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for nome(city #978)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for warqla(city #979)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - warqla Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for vaitupu(city #980)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - vaitupu Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for horta(city #981)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for dolgorukovo(city #982)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for cordoba(city #983)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for xining(city #984)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for nepomuceno(city #985)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for ribeira grande(city #986)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for seymchan(city #987)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for mullaitivu(city #988)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - mullaitivu Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for kurilsk(city #989)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for dom pedrito(city #990)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for manadhoo(city #991)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for sioux lookout(city #992)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for saskylakh(city #993)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for bacuit(city #994)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# KeyError - bacuit Skipped --- next city
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for cayenne(city #995)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for asau(city #996)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for poronaysk(city #997)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for mar del plata(city #998)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for bonavista(city #999)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# getting weather data for hofn(city #1000)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#put lists with data values into a dict...
weather_dict = {
    "City": cities,
    "lat": lat,
    "lng": lng,
    "max temp":max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
#...and make a dataframe out of it
weather_df = pd.DataFrame(weather_dict)
weather_df = weather_df.dropna()
#export to csv
weather_df.to_csv("city_weather_csv")
weather_df
# Out:
#               City      lat       lng  max temp  Humidity  Cloudiness  \
# 0         bilibino  68.0546  166.4372     -7.29      76.0       100.0
# 1     lloydminster  53.2835 -110.0016      9.00      53.0        75.0
# 2        aracataca  10.5918  -74.1898     25.56      81.0        97.0
# 3        hithadhoo  -0.6000   73.0833     28.40      71.0        18.0
# 4        grindavik  63.8424  -22.4338      6.00      87.0         0.0
# ..             ...      ...       ...       ...       ...         ...
# 995           asau  46.4333   26.4000      5.56      65.0       100.0
# 996      poronaysk  49.2167  143.1167      1.03      97.0       100.0
# 997  mar del plata -38.0023  -57.5575     21.67      64.0         0.0
# 998      bonavista  48.6499  -53.1147      5.56      87.0        91.0
# 999           hofn  64.2539  -15.2082      4.04      63.0        79.0
#
#      Wind Speed Country          Date
# 0          0.99      RU  1.619645e+09
# 1          3.60      CA  1.619645e+09
# 2          3.13      CO  1.619645e+09
# 3          2.86      MV  1.619645e+09
# 4          4.12      IS  1.619645e+09
# ..          ...     ...           ...
# 995        0.76      RO  1.619645e+09
# 996        3.12      RU  1.619645e+09
# 997        5.14      AR  1.619645e+09
# 998        3.60      CA  1.619645e+09
# 999        5.60      IS  1.619645e+09
#
# [926 rows x 9 columns]

# %%
#get the quantitative values from weather df to make new df to see that there arent any errors (eg. humidity > 100)
weather_df_numeric = weather_df[['lat','lng','max temp','Humidity','Cloudiness','Wind Speed','Date']]
#make list of functions to loop thru columns
function_list = ['count', 'mean', 'std', 'min', 'max']
#and a list of quantiles
quantiles = [.25,.5,.75]


weather_stats_df = weather_df_numeric.agg({"lat" : function_list})

for col in weather_df_numeric:
    col_stats_df = weather_df_numeric.agg({col : function_list})
    weather_stats_df[col] = col_stats_df

for q in quantiles:
    weather_stats_df = weather_stats_df.append(weather_stats_df.quantile(q= q))
weather_stats_df
# Out:
#               lat         lng    max temp    Humidity  Cloudiness  Wind Speed  \
# count  926.000000  926.000000  926.000000  926.000000  926.000000  926.000000
# mean    20.242599   20.592115   16.836544   69.579914   53.701944    3.089773
# std     31.501878   86.407715   10.946596   22.778453   37.908250    2.074863
# min    -54.800000 -179.166700  -14.290000    1.000000    0.000000    0.020000
# max     78.218600  179.316700   38.000000  100.000000  100.000000   13.890000
# 0.25    20.242599   20.592115   10.946596   22.778453   37.908250    2.074863
# 0.5     25.872239   53.499915   13.891570   46.179183   45.805097    2.582318
# 0.75    54.860239  132.862208   27.418272   84.789957   76.850972    8.489887
#
#                Date
# count  9.260000e+02
# mean   1.619645e+09
# std    1.228028e+02
# min    1.619644e+09
# max    1.619645e+09
# 0.25   9.260000e+02
# 0.5    8.098226e+08
# 0.75   1.619645e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def plot_weather(y_axis):
    x = weather_df[['lat']]
    y = weather_df[[y_axis]]
    lat_vs_humidity_plot = plt.scatter(x,y,edgecolors = "black")
    plt.title(f"Latitude and {y_axis} per city on {weather_date}")
    plt.xlabel("Latitude")
    plt.ylabel(y_axis)
    plt.grid(True)
    lat_vs_humidity_plot
    plt.savefig(f"Lat_{y_axis}.png")
plot_weather("max temp")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plot_weather("Humidity")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plot_weather('Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plot_weather('Wind Speed')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_df = weather_df[weather_df["lat"] > 0]

x_north = north_df['lat']
y_north = north_df['max temp']
plt.scatter(x_north,y_north,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("max temp")
plt.title(f"Latitude and Max Temp per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_north, y_north)
plt.grid(True)

fit = slope * x_north + intercept
plt.plot(x_north, fit, color ="r")

corr = round(st.pearsonr(x_north,y_north)[0],9)

print(f'coorelation = {corr}')

plt.savefig("north_lat_temp.png")
# Out:
# coorelation = -0.865713676

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_df = weather_df[weather_df["lat"] < 0]

x_south = south_df['lat']
y_south = south_df['max temp']
plt.scatter(x_south,y_south,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("max temp")
plt.title(f"Latitude and Max Temp per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_south, y_south)
plt.grid(True)

fit = slope * x_south + intercept
plt.plot(x_south, fit, color ="r")

corr = round(st.pearsonr(x_south,y_south)[0],9)

print(f'coorelation = {corr}')

plt.savefig("south_lat_temp.png")
# Out:
# coorelation = 0.704846332

# %%
#Based on the high correlation coefficient of temperature and latitude for both the north and south hemispheres, 
# it would seem that the temperature tends to increase as latitude approches zero

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_north = north_df['lat']
y_north = north_df['Humidity']
plt.scatter(x_north,y_north,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f"Latitude and Humidity per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_north, y_north)
plt.grid(True)

fit = slope * x_north + intercept
plt.plot(x_north, fit, color ="r")

corr = round(st.pearsonr(x_north,y_north)[0],9)

print(f'coorelation = {corr}')

plt.savefig("north_lat_humidity.png")
# Out:
# coorelation = 0.132194059

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_south = south_df['lat']
y_south = south_df['Humidity']
plt.scatter(x_south,y_south,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title(f"Latitude and Humidity per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_south, y_south)
plt.grid(True)

fit = slope * x_south + intercept
plt.plot(x_south, fit, color ="r")

corr = round(st.pearsonr(x_south,y_south)[0],9)

print(f'coorelation = {corr}')

plt.savefig("south_lat_humidity.png")
# Out:
# coorelation = 0.197632145

# %%
#based on the lack of correlation between latitude and humidity, it would seem that they are indipendent

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_north = north_df['lat']
y_north = north_df['Cloudiness']
plt.scatter(x_north,y_north,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title(f"Latitude and Cloudiness per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_north, y_north)
plt.grid(True)

fit = slope * x_north + intercept
plt.plot(x_north, fit, color ="r")

corr = round(st.pearsonr(x_north,y_north)[0],9)

print(f'coorelation = {corr}')

plt.savefig("north_lat_clouds.png")
# Out:
# coorelation = -0.00624862

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_south = south_df['lat']
y_south = south_df['Cloudiness']
plt.scatter(x_south,y_south,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title(f"Latitude and Cloudiness per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_south, y_south)
plt.grid(True)

fit = slope * x_south + intercept
plt.plot(x_south, fit, color ="r")

corr = round(st.pearsonr(x_south,y_south)[0],9)

print(f'coorelation = {corr}')

plt.savefig("south_lat_clouds.png")
# Out:
# coorelation = 0.196922224

# %%
#there is a mild correlation between cloudiness and latitude, but it is so mild that it probably isnt one
# influencing the other, but rather the fact that clouds cluster and are big and could possibly 
# tend a certain latitude towards being slightly "cloudier" b/c thats just where they happen to be that day.
#especially considering that both hemispheres are positively correlated

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_north = north_df['lat']
y_north = north_df['Wind Speed']
plt.scatter(x_north,y_north,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("wind speed (meters/sec)")
plt.title(f"Latitude and Wind Speed per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_north, y_north)
plt.grid(True)

fit = slope * x_north + intercept
plt.plot(x_north, fit, color ="r")

corr = round(st.pearsonr(x_north,y_north)[0],9)

print(f'coorelation = {corr}')

plt.savefig("north_lat_wind.png")
# Out:
# coorelation = -0.025061296

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_south = south_df['lat']
y_south = south_df['Wind Speed']
plt.scatter(x_south,y_south,edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (meter/sec)")
plt.title(f"Latitude and Wind Speed per city on {weather_date}")
lat_vs_temp_plot
slope, intercept, r, p, sem = st.linregress(x_south, y_south)
plt.grid(True)

fit = slope * x_south + intercept
plt.plot(x_south, fit, color ="r")

corr = round(st.pearsonr(x_south,y_south)[0],9)
print(f'coorelation = {corr}')

plt.savefig("south_lat_wind.png")
# Out:
# coorelation = -0.244526835

# %%
#there is basically no correlation between hemishphere and wind speed in the southern hemishpere, and a 
#very slight one in the north. given that there are more data points in the south it would seem probable
#that the correlation for the north would shrink with more data, 
#and cannot be verified to mean anything at its level now
